# %%
import cv2
import os
import torch
import json
import numpy as np
from tqdm.notebook import tqdm
from copy import deepcopy

from torchvision import datasets, transforms
from torch.utils.data import DataLoader

from mmcv.transforms import Compose
from mmdet.utils import get_test_pipeline_cfg

def read_json(json_path):
    with open(json_path) as f:
        data = json.load(f)
    return data

def read_txt(txt_path):
    with open(txt_path) as f:
        data = f.readlines()
    data = [x.strip() for x in data]
    return data

def preprocess(test_pipeline, image):
    if isinstance(image, np.ndarray):
        # Calling this method across libraries will result
        # in module unregistered error if not prefixed with mmdet.
        test_pipeline[0].type = 'mmdet.LoadImageFromNDArray'
    test_pipeline = Compose(test_pipeline)
    return test_pipeline(dict(img=image))

class CustomImageDataset(torch.utils.data.Dataset):
    def __init__(self, images_dir, annotations_json_path, transform=None):
        self.transform = transform
        self.images_dir = images_dir
        self.annotations_json = read_json(annotations_json_path)


    def __len__(self):
        return len(self.annotations_json['images'])

    def __getitem__(self, idx):
        image_dict = self.annotations_json['images'][idx]
        image_path = os.path.join(self.images_dir, image_dict['file_name'])
        image_id = image_dict['id']

        image = cv2.imread(image_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            transformed_images = self.transform(image)
        else:
            transformed_images = image

        return image_id, image_path, transformed_images


# calibrationDataloader = DataLoader(calibrationDataset, batch_size=32, shuffle=True)

# %%
import torch
from mmdet.apis import DetInferencer

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Resize([640, 640]),  # Resize
])

DEVICE = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
CONFIG_PATH = '/teamspace/studios/this_studio/mmdetection/rtmdet_tiny_8xb32-300e_coco.py'
WEIGHTS_PATH = '/teamspace/studios/this_studio/mmdetection/rtmdet_tiny_8xb32-300e_coco_20220902_112414-78e30dcc.pth'
EVAL_DATASET_SIZE = 5000
CALIBRATION_DATASET_SIZE = 1000
BATCH_SIZE = 64

ROOT_DATASET_DIR = '/teamspace/studios/this_studio/COCO'
IMAGES_DIR = os.path.join(ROOT_DATASET_DIR, 'images')
ANNOTATIONS_JSON_PATH = os.path.join(ROOT_DATASET_DIR, 'annotations/instances_val2017.json')
# ANNOTATIONS_JSON_PATH = "/home/shayaan/Desktop/aimet/my_mmdet/temp.json"

model = DetInferencer(model=CONFIG_PATH, weights=WEIGHTS_PATH, device=DEVICE)
evalDataset = CustomImageDataset(images_dir=IMAGES_DIR, annotations_json_path=ANNOTATIONS_JSON_PATH, transform=transform)
eval_data_loader = DataLoader(evalDataset, batch_size=BATCH_SIZE)
calibration_images = read_txt('/teamspace/studios/this_studio/aimet/Examples/torch/quantization/calibration_image_ids.txt')
calibration_data_loader = DataLoader(calibration_images, batch_size=BATCH_SIZE)

DEVICE
# Out:
# [2024-09-09 13:07:03,421] [INFO] [real_accelerator.py:203:get_accelerator] Setting ds_accelerator to cuda (auto detect)
#  [WARNING]  async_io requires the dev libaio .so object and headers but these were not found.
#  [WARNING]  async_io: please install the libaio-dev package with apt
#  [WARNING]  If libaio is already installed (perhaps from source), try setting the CFLAGS and LDFLAGS environment variables to where it can be found.
#  [WARNING]  Please specify the CUTLASS repo directory as environment variable $CUTLASS_PATH
# /bin/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
#  [WARNING]  NVIDIA Inference is only supported on Ampere and newer architectures
#  [WARNING]  sparse_attn requires a torch version >= 1.5 and < 2.0 but detected 2.2
#  [WARNING]  using untested triton version (2.2.0), only 1.0.0 is known to be compatible
# Loads checkpoint by local backend from path: /teamspace/studios/this_studio/mmdetection/rtmdet_tiny_8xb32-300e_coco_20220902_112414-78e30dcc.pth
# The model and loaded state dict do not match exactly
#
# unexpected key in source state_dict: data_preprocessor.mean, data_preprocessor.std
#
# 09/09 13:07:06 - mmengine - WARNING - Failed to search registry with scope "mmdet" in the "function" registry tree. As a workaround, the current "function" registry in "mmengine" is used to build instance. This may cause unexpected failure when running the built modules. Please check whether "mmdet" is a correct scope, or whether the registry is initialized.
# /usr/local/lib/python3.10/dist-packages/mmengine/visualization/visualizer.py:196: UserWarning: Failed to add <class 'mmengine.visualization.vis_backend.LocalVisBackend'>, please provide the `save_dir` argument.
#   warnings.warn(f'Failed to add {vis_backend.__class__}, '
# device(type='cuda', index=0)

# %%
from collections import OrderedDict
from copy import deepcopy

m = deepcopy(model.model)

def is_leaf(module): 
    return len(module._modules) == 0

def replace_bn(m):

    if is_leaf(m):
        return 

    for _, child in m.named_children(): 
        
        if "bn" in child._modules.keys():
            bn = child._modules.get("bn")
            bn_params = deepcopy(bn._parameters)
            bn_buffers = deepcopy(bn._buffers)
            new_bn = torch.nn.BatchNorm2d(bn.num_features, eps=bn.eps, momentum=bn.momentum, affine=bn.affine, track_running_stats=bn.track_running_stats)
            new_bn._parameters["weight"].data = bn_params["weight"].data
            new_bn._parameters["bias"].data = bn_params["bias"].data
            new_bn._buffers["running_mean"].data = bn_buffers["running_mean"].data
            new_bn._buffers["running_var"].data = bn_buffers["running_var"].data
            new_bn._buffers["num_batches_tracked"].data = bn_buffers["num_batches_tracked"].data
            child._modules["bn"] = new_bn
            
        replace_bn(child)

# %%
model = deepcopy(model.model)
replace_bn(model)

# %%
from aimet_torch.model_preparer import prepare_model

model = prepare_model(model)
# Out:
# 2024-09-09 13:07:08,580 - root - INFO - AIMET
# 2024-09-09 13:07:08,764 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage1.1.blocks.0.module_add}
# 2024-09-09 13:07:08,766 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage1.1.module_cat}
# 2024-09-09 13:07:08,767 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage1.1.attention.module_mul}
# 2024-09-09 13:07:08,768 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage2.1.blocks.0.module_add_1}
# 2024-09-09 13:07:08,769 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage2.1.module_cat_1}
# 2024-09-09 13:07:08,770 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage2.1.attention.module_mul_1}
# 2024-09-09 13:07:08,772 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage3.1.blocks.0.module_add_2}
# 2024-09-09 13:07:08,772 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage3.1.module_cat_2}
# 2024-09-09 13:07:08,773 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage3.1.attention.module_mul_2}
# 2024-09-09 13:07:08,774 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage4.1.module_cat_3}
# 2024-09-09 13:07:08,776 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage4.2.module_cat_4}
# 2024-09-09 13:07:08,777 - ModelPreparer - INFO - Functional         : Adding new module for node: {backbone.stage4.2.attention.module_mul_3}
# 2024-09-09 13:07:08,777 - ModelPreparer - INFO - Functional         : Adding new module for node: {neck.module_cat_5}
# 2024-09-09 13:07:08,779 - ModelPreparer - INFO - Functional         : Adding new module for node: {neck.top_down_blocks.0.module_cat_6}
# 2024-09-09 13:07:08,780 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {neck.module_upsample_1}
# 2024-09-09 13:07:08,781 - ModelPreparer - INFO - Functional         : Adding new module for node: {neck.module_cat_7}
# 2024-09-09 13:07:08,782 - ModelPreparer - INFO - Functional         : Adding new module for node: {neck.top_down_blocks.1.module_cat_8}
# 2024-09-09 13:07:08,783 - ModelPreparer - INFO - Functional         : Adding new module for node: {neck.module_cat_9}
# 2024-09-09 13:07:08,784 - ModelPreparer - INFO - Functional         : Adding new module for node: {neck.bottom_up_blocks.0.module_cat_10}
# 2024-09-09 13:07:08,785 - ModelPreparer - INFO - Functional         : Adding new module for node: {neck.module_cat_11}
# 2024-09-09 13:07:08,786 - ModelPreparer - INFO - Functional         : Adding new module for node: {neck.bottom_up_blocks.1.module_cat_12}
# 2024-09-09 13:07:08,787 - ModelPreparer - INFO - Functional         : Adding new module for node: {bbox_head.module_mul_4}
# 2024-09-09 13:07:08,789 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {bbox_head.cls_convs.0.0.module_conv_1}
# 2024-09-09 13:07:08,790 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {bbox_head.cls_convs.0.1.module_conv_1}
# 2024-09-09 13:07:08,791 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {bbox_head.reg_convs.0.0.module_conv_1}
# 2024-09-09 13:07:08,792 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {bbox_head.reg_convs.0.1.module_conv_1}
# 2024-09-09 13:07:08,793 - ModelPreparer - INFO - Functional         : Adding new module for node: {bbox_head.module_mul_5}
# 2024-09-09 13:07:08,795 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {bbox_head.cls_convs.0.0.module_conv_2}
# 2024-09-09 13:07:08,796 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {bbox_head.cls_convs.0.1.module_conv_2}
# 2024-09-09 13:07:08,797 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {bbox_head.reg_convs.0.0.module_conv_2}
# 2024-09-09 13:07:08,798 - ModelPreparer - INFO - Reused/Duplicate   : Adding new module for node: {bbox_head.reg_convs.0.1.module_conv_2}
# 2024-09-09 13:07:08,799 - ModelPreparer - INFO - Functional         : Adding new module for node: {bbox_head.module_mul_6}

# %%
def read_json(filename):
    with open(filename, 'r') as f:
        return json.load(f)

# %%
for k in dict(model.named_modules()).keys():
    print(k)
# Out:
# backbone
# backbone.stem
# backbone.stem.0
# backbone.stem.0.conv
# backbone.stem.0.bn
# backbone.stem.0.activate
# backbone.stem.0.activate.sigmoid
# backbone.stem.0.activate.mul
# backbone.stem.1
# backbone.stem.1.conv
# backbone.stem.1.bn
# backbone.stem.1.activate
# backbone.stem.1.activate.sigmoid
# backbone.stem.1.activate.mul
# backbone.stem.2
# backbone.stem.2.conv
# backbone.stem.2.bn
# backbone.stem.2.activate
# backbone.stem.2.activate.sigmoid
# backbone.stem.2.activate.mul
# backbone.stage1
# backbone.stage1.0
# backbone.stage1.0.conv
# backbone.stage1.0.bn
# backbone.stage1.0.activate
# backbone.stage1.0.activate.sigmoid
# backbone.stage1.0.activate.mul
# backbone.stage1.1
# backbone.stage1.1.short_conv
# backbone.stage1.1.short_conv.conv
# backbone.stage1.1.short_conv.bn
# backbone.stage1.1.short_conv.activate
# backbone.stage1.1.short_conv.activate.sigmoid
# backbone.stage1.1.short_conv.activate.mul
# backbone.stage1.1.main_conv
# backbone.stage1.1.main_conv.conv
# backbone.stage1.1.main_conv.bn
# backbone.stage1.1.main_conv.activate
# backbone.stage1.1.main_conv.activate.sigmoid
# backbone.stage1.1.main_conv.activate.mul
# backbone.stage1.1.blocks
# backbone.stage1.1.blocks.0
# backbone.stage1.1.blocks.0.conv1
# backbone.stage1.1.blocks.0.conv1.conv
# backbone.stage1.1.blocks.0.conv1.bn
# backbone.stage1.1.blocks.0.conv1.activate
# backbone.stage1.1.blocks.0.conv1.activate.sigmoid
# backbone.stage1.1.blocks.0.conv1.activate.mul
# backbone.stage1.1.blocks.0.conv2
# backbone.stage1.1.blocks.0.conv2.depthwise_conv
# backbone.stage1.1.blocks.0.conv2.depthwise_conv.conv
# backbone.stage1.1.blocks.0.conv2.depthwise_conv.bn
# backbone.stage1.1.blocks.0.conv2.depthwise_conv.activate
# backbone.stage1.1.blocks.0.conv2.depthwise_conv.activate.sigmoid
# backbone.stage1.1.blocks.0.conv2.depthwise_conv.activate.mul
# backbone.stage1.1.blocks.0.conv2.pointwise_conv
# backbone.stage1.1.blocks.0.conv2.pointwise_conv.conv
# backbone.stage1.1.blocks.0.conv2.pointwise_conv.bn
# backbone.stage1.1.blocks.0.conv2.pointwise_conv.activate
# backbone.stage1.1.blocks.0.conv2.pointwise_conv.activate.sigmoid
# backbone.stage1.1.blocks.0.conv2.pointwise_conv.activate.mul
# backbone.stage1.1.blocks.0.module_add
# backbone.stage1.1.attention
# backbone.stage1.1.attention.global_avgpool
# backbone.stage1.1.attention.fc
# backbone.stage1.1.attention.act
# backbone.stage1.1.attention.module_mul
# backbone.stage1.1.final_conv
# backbone.stage1.1.final_conv.conv
# backbone.stage1.1.final_conv.bn
# backbone.stage1.1.final_conv.activate
# backbone.stage1.1.final_conv.activate.sigmoid
# backbone.stage1.1.final_conv.activate.mul
# backbone.stage1.1.module_cat
# backbone.stage2
# backbone.stage2.0
# backbone.stage2.0.conv
# backbone.stage2.0.bn
# backbone.stage2.0.activate
# backbone.stage2.0.activate.sigmoid
# backbone.stage2.0.activate.mul
# backbone.stage2.1
# backbone.stage2.1.short_conv
# backbone.stage2.1.short_conv.conv
# backbone.stage2.1.short_conv.bn
# backbone.stage2.1.short_conv.activate
# backbone.stage2.1.short_conv.activate.sigmoid
# backbone.stage2.1.short_conv.activate.mul
# backbone.stage2.1.main_conv
# backbone.stage2.1.main_conv.conv
# backbone.stage2.1.main_conv.bn
# backbone.stage2.1.main_conv.activate
# backbone.stage2.1.main_conv.activate.sigmoid
# backbone.stage2.1.main_conv.activate.mul
# backbone.stage2.1.blocks
# backbone.stage2.1.blocks.0
# backbone.stage2.1.blocks.0.conv1
# backbone.stage2.1.blocks.0.conv1.conv
# backbone.stage2.1.blocks.0.conv1.bn
# backbone.stage2.1.blocks.0.conv1.activate
# backbone.stage2.1.blocks.0.conv1.activate.sigmoid
# backbone.stage2.1.blocks.0.conv1.activate.mul
# backbone.stage2.1.blocks.0.conv2
# backbone.stage2.1.blocks.0.conv2.depthwise_conv
# backbone.stage2.1.blocks.0.conv2.depthwise_conv.conv
# backbone.stage2.1.blocks.0.conv2.depthwise_conv.bn
# backbone.stage2.1.blocks.0.conv2.depthwise_conv.activate
# backbone.stage2.1.blocks.0.conv2.depthwise_conv.activate.sigmoid
# backbone.stage2.1.blocks.0.conv2.depthwise_conv.activate.mul
# backbone.stage2.1.blocks.0.conv2.pointwise_conv
# backbone.stage2.1.blocks.0.conv2.pointwise_conv.conv
# backbone.stage2.1.blocks.0.conv2.pointwise_conv.bn
# backbone.stage2.1.blocks.0.conv2.pointwise_conv.activate
# backbone.stage2.1.blocks.0.conv2.pointwise_conv.activate.sigmoid
# backbone.stage2.1.blocks.0.conv2.pointwise_conv.activate.mul
# backbone.stage2.1.blocks.0.module_add_1
# backbone.stage2.1.attention
# backbone.stage2.1.attention.global_avgpool
# backbone.stage2.1.attention.fc
# backbone.stage2.1.attention.act
# backbone.stage2.1.attention.module_mul_1
# backbone.stage2.1.final_conv
# backbone.stage2.1.final_conv.conv
# backbone.stage2.1.final_conv.bn
# backbone.stage2.1.final_conv.activate
# backbone.stage2.1.final_conv.activate.sigmoid
# backbone.stage2.1.final_conv.activate.mul
# backbone.stage2.1.module_cat_1
# backbone.stage3
# backbone.stage3.0
# backbone.stage3.0.conv
# backbone.stage3.0.bn
# backbone.stage3.0.activate
# backbone.stage3.0.activate.sigmoid
# backbone.stage3.0.activate.mul
# backbone.stage3.1
# backbone.stage3.1.short_conv
# backbone.stage3.1.short_conv.conv
# backbone.stage3.1.short_conv.bn
# backbone.stage3.1.short_conv.activate
# backbone.stage3.1.short_conv.activate.sigmoid
# backbone.stage3.1.short_conv.activate.mul
# backbone.stage3.1.main_conv
# backbone.stage3.1.main_conv.conv
# backbone.stage3.1.main_conv.bn
# backbone.stage3.1.main_conv.activate
# backbone.stage3.1.main_conv.activate.sigmoid
# backbone.stage3.1.main_conv.activate.mul
# backbone.stage3.1.blocks
# backbone.stage3.1.blocks.0
# backbone.stage3.1.blocks.0.conv1
# backbone.stage3.1.blocks.0.conv1.conv
# backbone.stage3.1.blocks.0.conv1.bn
# backbone.stage3.1.blocks.0.conv1.activate
# backbone.stage3.1.blocks.0.conv1.activate.sigmoid
# backbone.stage3.1.blocks.0.conv1.activate.mul
# backbone.stage3.1.blocks.0.conv2
# backbone.stage3.1.blocks.0.conv2.depthwise_conv
# backbone.stage3.1.blocks.0.conv2.depthwise_conv.conv
# backbone.stage3.1.blocks.0.conv2.depthwise_conv.bn
# backbone.stage3.1.blocks.0.conv2.depthwise_conv.activate
# backbone.stage3.1.blocks.0.conv2.depthwise_conv.activate.sigmoid
# backbone.stage3.1.blocks.0.conv2.depthwise_conv.activate.mul
# backbone.stage3.1.blocks.0.conv2.pointwise_conv
# backbone.stage3.1.blocks.0.conv2.pointwise_conv.conv
# backbone.stage3.1.blocks.0.conv2.pointwise_conv.bn
# backbone.stage3.1.blocks.0.conv2.pointwise_conv.activate
# backbone.stage3.1.blocks.0.conv2.pointwise_conv.activate.sigmoid
# backbone.stage3.1.blocks.0.conv2.pointwise_conv.activate.mul
# backbone.stage3.1.blocks.0.module_add_2
# backbone.stage3.1.attention
# backbone.stage3.1.attention.global_avgpool
# backbone.stage3.1.attention.fc
# backbone.stage3.1.attention.act
# backbone.stage3.1.attention.module_mul_2
# backbone.stage3.1.final_conv
# backbone.stage3.1.final_conv.conv
# backbone.stage3.1.final_conv.bn
# backbone.stage3.1.final_conv.activate
# backbone.stage3.1.final_conv.activate.sigmoid
# backbone.stage3.1.final_conv.activate.mul
# backbone.stage3.1.module_cat_2
# backbone.stage4
# backbone.stage4.0
# backbone.stage4.0.conv
# backbone.stage4.0.bn
# backbone.stage4.0.activate
# backbone.stage4.0.activate.sigmoid
# backbone.stage4.0.activate.mul
# backbone.stage4.1
# backbone.stage4.1.conv1
# backbone.stage4.1.conv1.conv
# backbone.stage4.1.conv1.bn
# backbone.stage4.1.conv1.activate
# backbone.stage4.1.conv1.activate.sigmoid
# backbone.stage4.1.conv1.activate.mul
# backbone.stage4.1.poolings
# backbone.stage4.1.poolings.0
# backbone.stage4.1.poolings.1
# backbone.stage4.1.poolings.2
# backbone.stage4.1.conv2
# backbone.stage4.1.conv2.conv
# backbone.stage4.1.conv2.bn
# backbone.stage4.1.conv2.activate
# backbone.stage4.1.conv2.activate.sigmoid
# backbone.stage4.1.conv2.activate.mul
# backbone.stage4.1.module_cat_3
# backbone.stage4.2
# backbone.stage4.2.short_conv
# backbone.stage4.2.short_conv.conv
# backbone.stage4.2.short_conv.bn
# backbone.stage4.2.short_conv.activate
# backbone.stage4.2.short_conv.activate.sigmoid
# backbone.stage4.2.short_conv.activate.mul
# backbone.stage4.2.main_conv
# backbone.stage4.2.main_conv.conv
# backbone.stage4.2.main_conv.bn
# backbone.stage4.2.main_conv.activate
# backbone.stage4.2.main_conv.activate.sigmoid
# backbone.stage4.2.main_conv.activate.mul
# backbone.stage4.2.blocks
# backbone.stage4.2.blocks.0
# backbone.stage4.2.blocks.0.conv1
# backbone.stage4.2.blocks.0.conv1.conv
# backbone.stage4.2.blocks.0.conv1.bn
# backbone.stage4.2.blocks.0.conv1.activate
# backbone.stage4.2.blocks.0.conv1.activate.sigmoid
# backbone.stage4.2.blocks.0.conv1.activate.mul
# backbone.stage4.2.blocks.0.conv2
# backbone.stage4.2.blocks.0.conv2.depthwise_conv
# backbone.stage4.2.blocks.0.conv2.depthwise_conv.conv
# backbone.stage4.2.blocks.0.conv2.depthwise_conv.bn
# backbone.stage4.2.blocks.0.conv2.depthwise_conv.activate
# backbone.stage4.2.blocks.0.conv2.depthwise_conv.activate.sigmoid
# backbone.stage4.2.blocks.0.conv2.depthwise_conv.activate.mul
# backbone.stage4.2.blocks.0.conv2.pointwise_conv
# backbone.stage4.2.blocks.0.conv2.pointwise_conv.conv
# backbone.stage4.2.blocks.0.conv2.pointwise_conv.bn
# backbone.stage4.2.blocks.0.conv2.pointwise_conv.activate
# backbone.stage4.2.blocks.0.conv2.pointwise_conv.activate.sigmoid
# backbone.stage4.2.blocks.0.conv2.pointwise_conv.activate.mul
# backbone.stage4.2.attention
# backbone.stage4.2.attention.global_avgpool
# backbone.stage4.2.attention.fc
# backbone.stage4.2.attention.act
# backbone.stage4.2.attention.module_mul_3
# backbone.stage4.2.final_conv
# backbone.stage4.2.final_conv.conv
# backbone.stage4.2.final_conv.bn
# backbone.stage4.2.final_conv.activate
# backbone.stage4.2.final_conv.activate.sigmoid
# backbone.stage4.2.final_conv.activate.mul
# backbone.stage4.2.module_cat_4
# neck
# neck.reduce_layers
# neck.reduce_layers.0
# neck.reduce_layers.0.conv
# neck.reduce_layers.0.bn
# neck.reduce_layers.0.activate
# neck.reduce_layers.0.activate.sigmoid
# neck.reduce_layers.0.activate.mul
# neck.reduce_layers.1
# neck.reduce_layers.1.conv
# neck.reduce_layers.1.bn
# neck.reduce_layers.1.activate
# neck.reduce_layers.1.activate.sigmoid
# neck.reduce_layers.1.activate.mul
# neck.upsample
# neck.top_down_blocks
# neck.top_down_blocks.0
# neck.top_down_blocks.0.short_conv
# neck.top_down_blocks.0.short_conv.conv
# neck.top_down_blocks.0.short_conv.bn
# neck.top_down_blocks.0.short_conv.activate
# neck.top_down_blocks.0.short_conv.activate.sigmoid
# neck.top_down_blocks.0.short_conv.activate.mul
# neck.top_down_blocks.0.main_conv
# neck.top_down_blocks.0.main_conv.conv
# neck.top_down_blocks.0.main_conv.bn
# neck.top_down_blocks.0.main_conv.activate
# neck.top_down_blocks.0.main_conv.activate.sigmoid
# neck.top_down_blocks.0.main_conv.activate.mul
# neck.top_down_blocks.0.blocks
# neck.top_down_blocks.0.blocks.0
# neck.top_down_blocks.0.blocks.0.conv1
# neck.top_down_blocks.0.blocks.0.conv1.conv
# neck.top_down_blocks.0.blocks.0.conv1.bn
# neck.top_down_blocks.0.blocks.0.conv1.activate
# neck.top_down_blocks.0.blocks.0.conv1.activate.sigmoid
# neck.top_down_blocks.0.blocks.0.conv1.activate.mul
# neck.top_down_blocks.0.blocks.0.conv2
# neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv
# neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.conv
# neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.bn
# neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.activate
# neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.activate.sigmoid
# neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.activate.mul
# neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv
# neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.conv
# neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.bn
# neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.activate
# neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.activate.sigmoid
# neck.top_down_blocks.0.blocks.0.conv2.pointwise_conv.activate.mul
# neck.top_down_blocks.0.final_conv
# neck.top_down_blocks.0.final_conv.conv
# neck.top_down_blocks.0.final_conv.bn
# neck.top_down_blocks.0.final_conv.activate
# neck.top_down_blocks.0.final_conv.activate.sigmoid
# neck.top_down_blocks.0.final_conv.activate.mul
# neck.top_down_blocks.0.module_cat_6
# neck.top_down_blocks.1
# neck.top_down_blocks.1.short_conv
# neck.top_down_blocks.1.short_conv.conv
# neck.top_down_blocks.1.short_conv.bn
# neck.top_down_blocks.1.short_conv.activate
# neck.top_down_blocks.1.short_conv.activate.sigmoid
# neck.top_down_blocks.1.short_conv.activate.mul
# neck.top_down_blocks.1.main_conv
# neck.top_down_blocks.1.main_conv.conv
# neck.top_down_blocks.1.main_conv.bn
# neck.top_down_blocks.1.main_conv.activate
# neck.top_down_blocks.1.main_conv.activate.sigmoid
# neck.top_down_blocks.1.main_conv.activate.mul
# neck.top_down_blocks.1.blocks
# neck.top_down_blocks.1.blocks.0
# neck.top_down_blocks.1.blocks.0.conv1
# neck.top_down_blocks.1.blocks.0.conv1.conv
# neck.top_down_blocks.1.blocks.0.conv1.bn
# neck.top_down_blocks.1.blocks.0.conv1.activate
# neck.top_down_blocks.1.blocks.0.conv1.activate.sigmoid
# neck.top_down_blocks.1.blocks.0.conv1.activate.mul
# neck.top_down_blocks.1.blocks.0.conv2
# neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv
# neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.conv
# neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.bn
# neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.activate
# neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.activate.sigmoid
# neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.activate.mul
# neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv
# neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.conv
# neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.bn
# neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.activate
# neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.activate.sigmoid
# neck.top_down_blocks.1.blocks.0.conv2.pointwise_conv.activate.mul
# neck.top_down_blocks.1.final_conv
# neck.top_down_blocks.1.final_conv.conv
# neck.top_down_blocks.1.final_conv.bn
# neck.top_down_blocks.1.final_conv.activate
# neck.top_down_blocks.1.final_conv.activate.sigmoid
# neck.top_down_blocks.1.final_conv.activate.mul
# neck.top_down_blocks.1.module_cat_8
# neck.downsamples
# neck.downsamples.0
# neck.downsamples.0.conv
# neck.downsamples.0.bn
# neck.downsamples.0.activate
# neck.downsamples.0.activate.sigmoid
# neck.downsamples.0.activate.mul
# neck.downsamples.1
# neck.downsamples.1.conv
# neck.downsamples.1.bn
# neck.downsamples.1.activate
# neck.downsamples.1.activate.sigmoid
# neck.downsamples.1.activate.mul
# neck.bottom_up_blocks
# neck.bottom_up_blocks.0
# neck.bottom_up_blocks.0.short_conv
# neck.bottom_up_blocks.0.short_conv.conv
# neck.bottom_up_blocks.0.short_conv.bn
# neck.bottom_up_blocks.0.short_conv.activate
# neck.bottom_up_blocks.0.short_conv.activate.sigmoid
# neck.bottom_up_blocks.0.short_conv.activate.mul
# neck.bottom_up_blocks.0.main_conv
# neck.bottom_up_blocks.0.main_conv.conv
# neck.bottom_up_blocks.0.main_conv.bn
# neck.bottom_up_blocks.0.main_conv.activate
# neck.bottom_up_blocks.0.main_conv.activate.sigmoid
# neck.bottom_up_blocks.0.main_conv.activate.mul
# neck.bottom_up_blocks.0.blocks
# neck.bottom_up_blocks.0.blocks.0
# neck.bottom_up_blocks.0.blocks.0.conv1
# neck.bottom_up_blocks.0.blocks.0.conv1.conv
# neck.bottom_up_blocks.0.blocks.0.conv1.bn
# neck.bottom_up_blocks.0.blocks.0.conv1.activate
# neck.bottom_up_blocks.0.blocks.0.conv1.activate.sigmoid
# neck.bottom_up_blocks.0.blocks.0.conv1.activate.mul
# neck.bottom_up_blocks.0.blocks.0.conv2
# neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv
# neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.conv
# neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.bn
# neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.activate
# neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.activate.sigmoid
# neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.activate.mul
# neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv
# neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.conv
# neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.bn
# neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.activate
# neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.activate.sigmoid
# neck.bottom_up_blocks.0.blocks.0.conv2.pointwise_conv.activate.mul
# neck.bottom_up_blocks.0.final_conv
# neck.bottom_up_blocks.0.final_conv.conv
# neck.bottom_up_blocks.0.final_conv.bn
# neck.bottom_up_blocks.0.final_conv.activate
# neck.bottom_up_blocks.0.final_conv.activate.sigmoid
# neck.bottom_up_blocks.0.final_conv.activate.mul
# neck.bottom_up_blocks.0.module_cat_10
# neck.bottom_up_blocks.1
# neck.bottom_up_blocks.1.short_conv
# neck.bottom_up_blocks.1.short_conv.conv
# neck.bottom_up_blocks.1.short_conv.bn
# neck.bottom_up_blocks.1.short_conv.activate
# neck.bottom_up_blocks.1.short_conv.activate.sigmoid
# neck.bottom_up_blocks.1.short_conv.activate.mul
# neck.bottom_up_blocks.1.main_conv
# neck.bottom_up_blocks.1.main_conv.conv
# neck.bottom_up_blocks.1.main_conv.bn
# neck.bottom_up_blocks.1.main_conv.activate
# neck.bottom_up_blocks.1.main_conv.activate.sigmoid
# neck.bottom_up_blocks.1.main_conv.activate.mul
# neck.bottom_up_blocks.1.blocks
# neck.bottom_up_blocks.1.blocks.0
# neck.bottom_up_blocks.1.blocks.0.conv1
# neck.bottom_up_blocks.1.blocks.0.conv1.conv
# neck.bottom_up_blocks.1.blocks.0.conv1.bn
# neck.bottom_up_blocks.1.blocks.0.conv1.activate
# neck.bottom_up_blocks.1.blocks.0.conv1.activate.sigmoid
# neck.bottom_up_blocks.1.blocks.0.conv1.activate.mul
# neck.bottom_up_blocks.1.blocks.0.conv2
# neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv
# neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.conv
# neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.bn
# neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.activate
# neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.activate.sigmoid
# neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.activate.mul
# neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv
# neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.conv
# neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.bn
# neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.activate
# neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.activate.sigmoid
# neck.bottom_up_blocks.1.blocks.0.conv2.pointwise_conv.activate.mul
# neck.bottom_up_blocks.1.final_conv
# neck.bottom_up_blocks.1.final_conv.conv
# neck.bottom_up_blocks.1.final_conv.bn
# neck.bottom_up_blocks.1.final_conv.activate
# neck.bottom_up_blocks.1.final_conv.activate.sigmoid
# neck.bottom_up_blocks.1.final_conv.activate.mul
# neck.bottom_up_blocks.1.module_cat_12
# neck.out_convs
# neck.out_convs.0
# neck.out_convs.0.conv
# neck.out_convs.0.bn
# neck.out_convs.0.activate
# neck.out_convs.0.activate.sigmoid
# neck.out_convs.0.activate.mul
# neck.out_convs.1
# neck.out_convs.1.conv
# neck.out_convs.1.bn
# neck.out_convs.1.activate
# neck.out_convs.1.activate.sigmoid
# neck.out_convs.1.activate.mul
# neck.out_convs.2
# neck.out_convs.2.conv
# neck.out_convs.2.bn
# neck.out_convs.2.activate
# neck.out_convs.2.activate.sigmoid
# neck.out_convs.2.activate.mul
# neck.module_cat_5
# neck.module_upsample_1
# neck.module_cat_7
# neck.module_cat_9
# neck.module_cat_11
# bbox_head
# bbox_head.cls_convs
# bbox_head.cls_convs.0
# bbox_head.cls_convs.0.0
# bbox_head.cls_convs.0.0.conv
# bbox_head.cls_convs.0.0.bn
# bbox_head.cls_convs.0.0.activate
# bbox_head.cls_convs.0.0.activate.sigmoid
# bbox_head.cls_convs.0.0.activate.mul
# bbox_head.cls_convs.0.0.module_conv_1
# bbox_head.cls_convs.0.0.module_conv_2
# bbox_head.cls_convs.0.1
# bbox_head.cls_convs.0.1.conv
# bbox_head.cls_convs.0.1.bn
# bbox_head.cls_convs.0.1.activate
# bbox_head.cls_convs.0.1.activate.sigmoid
# bbox_head.cls_convs.0.1.activate.mul
# bbox_head.cls_convs.0.1.module_conv_1
# bbox_head.cls_convs.0.1.module_conv_2
# bbox_head.cls_convs.1
# bbox_head.cls_convs.1.0
# bbox_head.cls_convs.1.0.bn
# bbox_head.cls_convs.1.0.activate
# bbox_head.cls_convs.1.0.activate.sigmoid
# bbox_head.cls_convs.1.0.activate.mul
# bbox_head.cls_convs.1.1
# bbox_head.cls_convs.1.1.bn
# bbox_head.cls_convs.1.1.activate
# bbox_head.cls_convs.1.1.activate.sigmoid
# bbox_head.cls_convs.1.1.activate.mul
# bbox_head.cls_convs.2
# bbox_head.cls_convs.2.0
# bbox_head.cls_convs.2.0.bn
# bbox_head.cls_convs.2.0.activate
# bbox_head.cls_convs.2.0.activate.sigmoid
# bbox_head.cls_convs.2.0.activate.mul
# bbox_head.cls_convs.2.1
# bbox_head.cls_convs.2.1.bn
# bbox_head.cls_convs.2.1.activate
# bbox_head.cls_convs.2.1.activate.sigmoid
# bbox_head.cls_convs.2.1.activate.mul
# bbox_head.rtm_cls
# bbox_head.rtm_cls.0
# bbox_head.rtm_cls.1
# bbox_head.rtm_cls.2
# bbox_head.reg_convs
# bbox_head.reg_convs.0
# bbox_head.reg_convs.0.0
# bbox_head.reg_convs.0.0.conv
# bbox_head.reg_convs.0.0.bn
# bbox_head.reg_convs.0.0.activate
# bbox_head.reg_convs.0.0.activate.sigmoid
# bbox_head.reg_convs.0.0.activate.mul
# bbox_head.reg_convs.0.0.module_conv_1
# bbox_head.reg_convs.0.0.module_conv_2
# bbox_head.reg_convs.0.1
# bbox_head.reg_convs.0.1.conv
# bbox_head.reg_convs.0.1.bn
# bbox_head.reg_convs.0.1.activate
# bbox_head.reg_convs.0.1.activate.sigmoid
# bbox_head.reg_convs.0.1.activate.mul
# bbox_head.reg_convs.0.1.module_conv_1
# bbox_head.reg_convs.0.1.module_conv_2
# bbox_head.reg_convs.1
# bbox_head.reg_convs.1.0
# bbox_head.reg_convs.1.0.bn
# bbox_head.reg_convs.1.0.activate
# bbox_head.reg_convs.1.0.activate.sigmoid
# bbox_head.reg_convs.1.0.activate.mul
# bbox_head.reg_convs.1.1
# bbox_head.reg_convs.1.1.bn
# bbox_head.reg_convs.1.1.activate
# bbox_head.reg_convs.1.1.activate.sigmoid
# bbox_head.reg_convs.1.1.activate.mul
# bbox_head.reg_convs.2
# bbox_head.reg_convs.2.0
# bbox_head.reg_convs.2.0.bn
# bbox_head.reg_convs.2.0.activate
# bbox_head.reg_convs.2.0.activate.sigmoid
# bbox_head.reg_convs.2.0.activate.mul
# bbox_head.reg_convs.2.1
# bbox_head.reg_convs.2.1.bn
# bbox_head.reg_convs.2.1.activate
# bbox_head.reg_convs.2.1.activate.sigmoid
# bbox_head.reg_convs.2.1.activate.mul
# bbox_head.rtm_reg
# bbox_head.rtm_reg.0
# bbox_head.rtm_reg.1
# bbox_head.rtm_reg.2
# bbox_head.module_mul_4
# bbox_head.module_mul_5
# bbox_head.module_mul_6

# %%
modules_to_change = ["backbone.stage2.1.blocks.0.conv2.depthwise_conv.conv", "backbone.stage1.1.blocks.0.conv2.depthwise_conv.conv", "backbone.stage2.1.blocks.0.conv2.pointwise_conv.conv", "backbone.stage3.1.blocks.0.conv2.depthwise_conv.conv", "backbone.stage4.2.blocks.0.conv2.depthwise_conv.conv", "neck.top_down_blocks.0.blocks.0.conv2.depthwise_conv.conv", "neck.top_down_blocks.1.blocks.0.conv2.depthwise_conv.conv", "neck.bottom_up_blocks.0.blocks.0.conv2.depthwise_conv.conv", "neck.bottom_up_blocks.1.blocks.0.conv2.depthwise_conv.conv"]

# %%
from glob import glob

DIR = "./quant_analyzer_int16"
MODULE = modules_to_change[0]

stats_path = os.path.join(DIR, "activations_pdf", MODULE)
stats_path = glob(f"{stats_path}*.json")

for s in stats_path:
    print(s)
# os.path.exists(stats_path)

# %%
obj = read_json(stats_path[0])

pdfs = obj["pdfs"]
encoding_min = obj["encoding_min"]
encoding_max = obj["encoding_max"]

encoding_min, encoding_max
# Out:
# (-14.177273750305176, 14.313347816467285)

# %%
from pprint import pprint

pdfs = {float(k):v for k, v in pdfs.items()}
pdfs = {k:v for k, v in sorted(pdfs.items(), key=lambda x: x[0], reverse=True)[::-1]}

pprint(pdfs)
# Out:
# {0.0: [-38.340370178222656,
#        -38.186466217041016,
#        -38.03255844116211,
#        -37.87865447998047,
#        -37.72474670410156,
#        -37.57084274291992,
#        -37.416934967041016,
#        -37.263031005859375,
#        -37.10912322998047,
#        -36.95521926879883,
#        -36.80131149291992,
#        -36.64740753173828,
#        -36.493499755859375,
#        -36.339595794677734,
#        -36.18568801879883,
#        -36.03178405761719,
#        -35.87787628173828,
#        -35.72397232055664,
#        -35.570068359375,
#        -35.416160583496094,
#        -35.26225662231445,
#        -35.10834884643555,
#        -34.954444885253906,
#        -34.800537109375,
#        -34.64663314819336,
#        -34.49272537231445,
#        -34.33882141113281,
#        -34.184913635253906,
#        -34.031009674072266,
#        -33.87710189819336,
#        -33.72319793701172,
#        -33.56929016113281,
#        -33.41538619995117,
#        -33.26148223876953,
#        -33.107574462890625,
#        -32.953670501708984,
#        -32.79976272583008,
#        -32.64585876464844,
#        -32.49195098876953,
#        -32.33804702758789,
#        -32.184139251708984,
#        -32.030235290527344,
#        -31.876327514648438,
#        -31.722423553466797,
#        -31.568517684936523,
#        -31.41461181640625,
#        -31.260705947875977,
#        -31.106800079345703,
#        -30.95289421081543,
#        -30.798988342285156,
#        -30.645082473754883,
#        -30.49117660522461,
#        -30.337270736694336,
#        -30.183364868164062,
#        -30.029460906982422,
#        -29.875553131103516,
#        -29.721649169921875,
#        -29.56774139404297,
#        -29.413837432861328,
#        -29.259929656982422,
#        -29.10602569580078,
#        -28.952119827270508,
#        -28.798213958740234,
#        -28.64430809020996,
#        -28.490402221679688,
#        -28.336496353149414,
#        -28.18259048461914,
#        -28.028684616088867,
#        -27.874778747558594,
#        -27.720874786376953,
#        -27.566967010498047,
#        -27.413063049316406,
#        -27.2591552734375,
#        -27.10525131225586,
#        -26.951343536376953,
#        -26.797439575195312,
#        -26.64353370666504,
#        -26.489627838134766,
#        -26.335721969604492,
#        -26.18181610107422,
#        -26.027910232543945,
#        -25.874004364013672,
#        -25.7200984954834,
#        -25.566192626953125,
#        -25.41228675842285,
#        -25.258380889892578,
#        -25.104476928710938,
#        -24.95056915283203,
#        -24.79666519165039,
#        -24.642757415771484,
#  0.0187597599029541: [5.368862152099609],
#  0.020707268397013343: [6.600109100341797],
#  0.021276906331380206: [0.9055976867675781],
#  0.024293964385986327: [3.6758995056152344],
#  0.02438244946797689: [3.5219955444335938],
#  0.026298117955525717: [-1.0951805114746094],
#  0.027500129063924152: [1.0595016479492188],
#  0.02825553957621256: [-1.5568962097167969],
#  0.02981157048543294: [0.5977859497070312],
#  0.030234614054361977: [0.443878173828125],
#  0.031725079218546545: [0.7516899108886719],
#  0.038752562840779624: [-0.0178375244140625],
#  0.039079779942830406: [0.2899742126464844],
#  0.04103001403808594: [0.13606643676757812],
#  0.045344938278198244: [-1.24908447265625],
#  0.04709142303466797: [3.3680877685546875],
#  0.04885736274719238: [-1.4029922485351562],
#  0.049329179763793946: [3.214183807373047],
#  0.04970301628112792: [-0.17174530029296875]}

# %%
vals = [item for sublist in list(pdfs.values()) for item in sublist]
min(vals), max(vals)
# Out:
# (-77.95208740234375, 85.07522583007812)

# %%
pdfs.pop(0.0)
vals = [item for sublist in list(pdfs.values()) for item in sublist]
min(vals), max(vals)
# Out:
# (-28.820568084716797, 34.986595153808594)

# %%
pprint(pdfs)
# Out:
# {1.5894571940104166e-09: [-28.820568084716797,
#                           -26.587318420410156,
#                           -26.26828384399414,
#                           -25.311176300048828],
#  1.5894571940104168e-09: [-24.992141723632812, -24.67310333251953],
#  1.589457194010417e-09: [31.477203369140625,
#                          33.71044921875,
#                          34.986595153808594],
#  3.178914388020833e-09: [31.158164978027344, 31.796234130859375],
#  4.768371582031251e-09: [30.520095825195312,
#                          32.115272521972656,
#                          32.43431091308594],
#  6.357828776041666e-09: [-21.482746124267578],
#  6.357828776041667e-09: [-23.71599578857422, -23.396961212158203],
#  6.357828776041668e-09: [-24.0350341796875],
#  7.947285970052083e-09: [-24.354068756103516,
#                          -23.077926635742188,
#                          -22.758888244628906,
#                          -22.120819091796875],
#  9.5367431640625e-09: [30.839126586914062],
#  1.2715657552083334e-08: [-21.163711547851562],
#  1.52587890625e-08: [30.20105743408203],
#  1.589457194010417e-08: [-20.525638580322266],
#  1.7484029134114587e-08: [-21.801780700683594, -20.84467315673828],
#  1.9073486328125e-08: [-22.43985366821289],
#  2.002716064453125e-08: [29.56298828125],
#  2.5431315104166665e-08: [29.88201904296875],
#  2.7020772298177085e-08: [-19.88756561279297],
#  2.7974446614583336e-08: [29.24394989013672],
#  3.496805826822917e-08: [-20.20660400390625],
#  3.4968058268229173e-08: [-19.568531036376953],
#  3.973642985026042e-08: [28.924911499023438],
#  4.7683715820312496e-08: [-18.61142349243164],
#  5.1180521647135425e-08: [28.605880737304688],
#  5.499521891276042e-08: [-18.930458068847656],
#  5.722045898437499e-08: [-19.249496459960938],
#  7.152557373046873e-08: [-18.292388916015625],
#  8.106231689453124e-08: [-17.01624298095703],
#  9.377797444661458e-08: [-17.973350524902344],
#  9.69568888346354e-08: [-17.654315948486328],
#  9.918212890625001e-08: [28.286842346191406],
#  1.0331471761067707e-07: [-17.335281372070312],
#  1.0553995768229168e-07: [27.967803955078125],
#  1.2556711832682293e-07: [-16.697208404541016],
